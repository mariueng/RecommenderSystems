# %%
# This notebook tests different implicit ratings and how to obtain missing values

import pandas as pd
import numpy as np
import os
import json

# %%
# Load datasets
def load_active_data(path):
    """
        Load events from files and convert to dataframe.
    """
    map_lst=[]
    for f in os.listdir(path):
        file_name=os.path.join(path, f)
        if os.path.isfile(file_name):
            for line in open(file_name):
                obj = json.loads(line.strip())
                if obj is not None:
                    map_lst.append(obj)
    return pd.DataFrame(map_lst)

events = load_active_data('active1000')
users = pd.read_csv('data/users.csv')
items = pd.read_csv('data/articles.csv')

# %%
from sklearn import preprocessing
# Impute missing activeTime values by the mean
events['activeTime'].fillna(events['activeTime'].mean(), inplace=True)

# Normalize activeTime values in a new column
scaler = preprocessing.MinMaxScaler()
events['normalized_activeTime'] = scaler.fit_transform(events['activeTime'].values.reshape(-1,1))

# %%
# Initiate ratings matrix
n_users = len(users)
n_items = len(items)

ratings = np.zeros((n_users, n_items))
print(f'Rating matrix shape: {n_users} x {n_items}')
# Out:
# Rating matrix shape: 1000 x 20344

# %%
def prepare_data(df):
    # Drop all documents with no ID
    df = df[~df['documentId'].isnull()]
    # Drop all duplicates of same user and document
    df = df.drop_duplicates(subset=['userId', 'documentId']).reset_index(drop=True)
    # Sort by userId and time
    df = df.sort_values(by=['userId', 'time'])
    n_users = df['userId'].nunique()
    n_items = df['documentId'].nunique()

    # Intialize ratings matrix
    ratings = np.zeros((n_users, n_items))
    # Check that there are no duplicate users
    new_user = df['userId'].values[1:] != df['userId'].values[:-1]
    # Convert to truth matrix
    new_user = np.r_[True, new_user]
    # Create new user ID: uid
    df['uid'] = np.cumsum(new_user)
    # Get all unique documents
    item_ids = df['documentId'].unique().tolist()
    # Create new dataframe with document and new document ID: tid
    new_df = pd.DataFrame({'documentId':item_ids, 'tid':range(1,len(item_ids)+1)})
    # Merge uid and tid on documentId
    df = pd.merge(df, new_df, on='documentId', how='outer')
    # Create our lookup table for interactions between users and documents
    df_ext = df[['uid', 'tid', 'normalized_activeTime']]
    # Return lookup table, empty ratings matrix and mapper to lookup documentId
    mapper = df
    return df_ext, ratings, mapper

# %%
df_ext, ratings, mapper = prepare_data(events)

# %%
def fill_ratings_matrix(df_ext, ratings):
    # Fill ratings matrix
    for row in df_ext.itertuples():
        ratings[row[1] - 1, row[2] - 1] = row[3]
    return ratings

# %%
ratings_active_time = fill_ratings_matrix(df_ext, ratings)

# %%
def train_test_split(ratings, fraction):
    test = np.zeros(ratings.shape)
    train = ratings.copy()
    for user in range(ratings.shape[0]):
        size = int(len(ratings[user, :].nonzero()[0]) * fraction)
        test_ratings = np.random.choice(ratings[user, :].nonzero()[0],
                                        size=size,
                                        replace=False)
        train[user, test_ratings] = 0.
        test[user, test_ratings] = ratings[user, test_ratings]
    
    assert(np.all((train * test) == 0))
    return train, test

# %%
train, test = train_test_split(ratings_active_time, fraction=0.2)

# %%
def evaluate(pred, actual, k):
    """
    Evaluate recommendations according to recall@k and ARHR@k
    """
    total_num = len(actual)
    tp = 0.
    arhr = 0.
    for p, t in zip(pred, actual):
        if t in p:
            tp += 1.
            arhr += 1./float(p.index(t) + 1.)
    recall = tp / float(total_num)
    arhr = arhr / len(actual)
    print("Recall@{} is {:.4f}".format(k, recall))
    print("ARHR@{} is {:.4f}".format(k, arhr))

# %%
from ExplicitMF import ExplicitMF

model = ExplicitMF(train, n_factors=40, user_reg=0.0, item_reg=0.0)
iter_array = [1, 2, 5, 10, 25, 50, 100]
model.calculate_learning_curve(iter_array, test)
# pe.plot_learning_curve(iter_array, model)
# Out:
# Iteration: 1
# Train mse: 0.0063307287373460105
# Test mse: 0.007992827481427708
# Iteration: 2
# Train mse: 0.005360262996855851
# Test mse: 0.00785802155699963
# Iteration: 5
# Train mse: 0.005141579391837787
# Test mse: 0.00783260152512132
# Iteration: 10
# Train mse: 0.005126197113602062
# Test mse: 0.007833063793007085
# Iteration: 25
# Current iteration: 10
# Train mse: 0.0051226825163467535
# Test mse: 0.007831703992359093
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.005121940319364312
# Test mse: 0.007832510400614957
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.0051218088459912235
# Test mse: 0.007832225202220818

# %%
from ExplicitMF import ExplicitMF

model = ExplicitMF(train, n_factors=20)
iter_array = [1, 2, 5, 10, 25] # , 50, 100
model.calculate_learning_curve(iter_array, test)
# pe.plot_learning_curve(iter_array, model)

# %%
# latent_factors = [5, 10, 20, 40, 80]
# regularizations = [0.01, 0.1, 1., 10., 100.]
# regularizations.sort()
# iter_array = [1, 2, 5, 10, 25, 50, 100]

# best_params = {}
# best_params['n_factors'] = latent_factors[0]
# best_params['reg'] = regularizations[0]
# best_params['n_iter'] = 0
# best_params['train_mse'] = np.inf
# best_params['test_mse'] = np.inf
# best_params['model'] = None

# for fact in latent_factors:
#     print('Factors: {}'.format(fact))
#     for reg in regularizations:
#         print('Regularization: {}'.format(reg))
#         MF_ALS = ExplicitMF(train, n_factors=fact, \
#                             user_reg=reg, item_reg=reg)
#         MF_ALS.calculate_learning_curve(iter_array, test)
#         min_idx = np.argmin(MF_ALS.test_mse)
#         if MF_ALS.test_mse[min_idx] < best_params['test_mse']:
#             best_params['n_factors'] = fact
#             best_params['reg'] = reg
#             best_params['n_iter'] = iter_array[min_idx]
#             best_params['train_mse'] = MF_ALS.train_mse[min_idx]
#             best_params['test_mse'] = MF_ALS.test_mse[min_idx]
#             best_params['model'] = MF_ALS
#             print('New optimal hyperparameters')
#             print(pd.Series(best_params))
# Out:
# Factors: 5
# Regularization: 0.01
# Iteration: 1
# Train mse: 0.00928381606535367
# Test mse: 0.00919614814695353
# Iteration: 2
# Train mse: 0.0074713924941245645
# Test mse: 0.0077598610090102845
# Iteration: 5
# Train mse: 0.007202453729419021
# Test mse: 0.00753825485666459
# Iteration: 10
# Train mse: 0.007127709977931498
# Test mse: 0.00746137043410134
# Iteration: 25
# Current iteration: 10
# Train mse: 0.007084179556394345
# Test mse: 0.0073957017675375806
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.007068766124538351
# Test mse: 0.007382312693170288
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.0070605027498709064
# Test mse: 0.007374371269504115
# New optimal hyperparameters
# n_factors                                                5
# reg                                                   0.01
# n_iter                                                 100
# train_mse                                         0.007061
# test_mse                                          0.007374
# model        <ExplicitMF.ExplicitMF object at 0x372990fd0>
# dtype: object
# Regularization: 0.1
# Iteration: 1
# Train mse: 0.00980778382059364
# Test mse: 0.009698275724255348
# Iteration: 2
# Train mse: 0.007218696552269347
# Test mse: 0.007556280510082742
# Iteration: 5
# Train mse: 0.007127860469546516
# Test mse: 0.0074705084973345
# Iteration: 10
# Train mse: 0.007092767835879499
# Test mse: 0.007419478241452245
# Iteration: 25
# Current iteration: 10
# Train mse: 0.007075330175622191
# Test mse: 0.00738847419760385
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.007069209130878143
# Test mse: 0.007380981933761448
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.0070650616232238676
# Test mse: 0.007376454142011207
# Regularization: 1.0
# Iteration: 1
# Train mse: 0.009879718209475606
# Test mse: 0.00976728135705679
# Iteration: 2
# Train mse: 0.007618766260494845
# Test mse: 0.007614690885994166
# Iteration: 5
# Train mse: 0.007119748771422743
# Test mse: 0.007396114415581621
# Iteration: 10
# Train mse: 0.007141942666303363
# Test mse: 0.007416269554360734
# Iteration: 25
# Current iteration: 10
# Train mse: 0.007165298774935765
# Test mse: 0.007445422184792959
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.007167746593920991
# Test mse: 0.007448762176590051
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.007167797406086933
# Test mse: 0.007448844789354846
# Regularization: 10.0
# Iteration: 1
# Train mse: 0.009887097540584883
# Test mse: 0.009774366266749166
# Iteration: 2
# Train mse: 0.009845202692301021
# Test mse: 0.009734160747534354
# Iteration: 5
# Train mse: 0.008367548370320065
# Test mse: 0.008316932557322725
# Iteration: 10
# Train mse: 0.00836732397814963
# Test mse: 0.008316717465494896
# Iteration: 25
# Current iteration: 10
# Train mse: 0.008367323978846703
# Test mse: 0.008316717465946175
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.008367323978847338
# Test mse: 0.00831671746594664
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.008367323978847338
# Test mse: 0.00831671746594664
# Regularization: 100.0
# Iteration: 1
# Train mse: 0.009887849453128053
# Test mse: 0.00977508876853971
# Iteration: 2
# Train mse: 0.009887935412804829
# Test mse: 0.009775171323429314
# Iteration: 5
# Train mse: 0.0098879358635817
# Test mse: 0.009775171756038621
# Iteration: 10
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 25
# Current iteration: 10
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Factors: 10
# Regularization: 0.01
# Iteration: 1
# Train mse: 0.009502116480797391
# Test mse: 0.009409683113204613
# Iteration: 2
# Train mse: 0.007007807371090433
# Test mse: 0.0077113363527409415
# Iteration: 5
# Train mse: 0.006759952869262362
# Test mse: 0.007561758393003603
# Iteration: 10
# Train mse: 0.006698853628881894
# Test mse: 0.007484864794112927
# Iteration: 25
# Current iteration: 10
# Train mse: 0.00665981373479518
# Test mse: 0.007430771425735198
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.006645175227623869
# Test mse: 0.007412527428620076
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.006638418021020079
# Test mse: 0.007405646215517695
# Regularization: 0.1
# Iteration: 1
# Train mse: 0.009835508758583937
# Test mse: 0.009725371707573314
# Iteration: 2
# Train mse: 0.00686642750098163
# Test mse: 0.007577433787300595
# Iteration: 5
# Train mse: 0.006682147099605651
# Test mse: 0.0074653624831347055
# Iteration: 10
# Train mse: 0.006663178808288854
# Test mse: 0.007447253983298529
# Iteration: 25
# Current iteration: 10
# Train mse: 0.006653900751097521
# Test mse: 0.007423147021375028
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.006650039262161779
# Test mse: 0.007413617195415483
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0
teration: 10
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 25
# Current iteration: 10
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Factors: 80
# Regularization: 0.01
# Iteration: 1
# Train mse: 0.00944657266582007
# Test mse: 0.009404191888282202
# Iteration: 2
# Train mse: 0.004305882187327528
# Test mse: 0.008228403456833873
# Iteration: 5
# Train mse: 0.004046720301444448
# Test mse: 0.008203186155116244
# Iteration: 10
# Train mse: 0.004005360627279032
# Test mse: 0.00814932342486474
# Iteration: 25
# Current iteration: 10
# Train mse: 0.003981863442864981
# Test mse: 0.008106480466929852
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.003971595072471164
# Test mse: 0.008091124626283952
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.003964952589149327
# Test mse: 0.008084735197134851
# Regularization: 0.1
# Iteration: 1
# Train mse: 0.009838369677963473
# Test mse: 0.009733200314897954
# Iteration: 2
# Train mse: 0.0041877150948691965
# Test mse: 0.00808294692195101
# Iteration: 5
# Train mse: 0.003995491164030139
# Test mse: 0.008106409785702276
# Iteration: 10
# Train mse: 0.003983982510727657
# Test mse: 0.008095966654239084
# Iteration: 25
# Current iteration: 10
# Train mse: 0.003991050334146633
# Test mse: 0.008081269219411602
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.003994482460769429
# Test mse: 0.008070528692726984
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.003993541310998588
# Test mse: 0.008064125631297553
# Regularization: 1.0
# Iteration: 1
# Train mse: 0.009882701962793285
# Test mse: 0.009770732833235544
# Iteration: 2
# Train mse: 0.007228879338346678
# Test mse: 0.0075105458155005885
# Iteration: 5
# Train mse: 0.00441325276284871
# Test mse: 0.007896981558190824
# Iteration: 10
# Train mse: 0.004395504722580259
# Test mse: 0.007920246175533227
# Iteration: 25
# Current iteration: 10
# Train mse: 0.004400984150698007
# Test mse: 0.007947911868057921
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.004401684473133119
# Test mse: 0.007950547983504003
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.004401935046817226
# Test mse: 0.007950827016692561
# Regularization: 10.0
# Iteration: 1
# Train mse: 0.00988741445056975
# Test mse: 0.00977472696544836
# Iteration: 2
# Train mse: 0.009863910320914573
# Test mse: 0.009752123489250383
# Iteration: 5
# Train mse: 0.008366370689694338
# Test mse: 0.008315803737361504
# Iteration: 10
# Train mse: 0.00836732392593408
# Test mse: 0.008316717426972384
# Iteration: 25
# Current iteration: 10
# Train mse: 0.008367323978813582
# Test mse: 0.008316717465921903
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.008367323978847338
# Test mse: 0.00831671746594664
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.008367323978847338
# Test mse: 0.00831671746594664
# Regularization: 100.0
# Iteration: 1
# Train mse: 0.009887900135682868
# Test mse: 0.009775142512621333
# Iteration: 2
# Train mse: 0.00988793570241367
# Test mse: 0.009775171601443854
# Iteration: 5
# Train mse: 0.009887935863581738
# Test mse: 0.009775171756038661
# Iteration: 10
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 25
# Current iteration: 10
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.009887935863581764
# Test mse: 0.009775171756038686

# %%
# best_als_model = best_params['model']
# pe.plot_learning_curve(iter_array, best_als_model)

# %%
best_params
# Out:
# {'n_factors': 5,
#  'reg': 0.01,
#  'n_iter': 100,
#  'train_mse': 0.0070605027498709064,
#  'test_mse': 0.007374371269504115,
#  'model': <ExplicitMF.ExplicitMF at 0x372990fd0>}

# %%
predictions = best_als_model.predict()

# %%
best_als_model.user_vecs
# Out:
# array([[ 0.06151095,  0.01758448, -0.04733656, -0.03496622,  0.04155669],
#        [-0.10089499, -0.11872518,  0.23320691,  0.21823995,  0.09114177],
#        [ 0.01110613, -0.00595552, -0.00554942, -0.01199448,  0.01889704],
#        ...,
#        [ 0.01833016, -0.01312439,  0.00715622,  0.00320009,  0.00712018],
#        [ 0.06914808, -0.01410983, -0.00363666, -0.04304837,  0.0336022 ],
#        [ 0.03785728,  0.00811067,  0.01084138,  0.02410091, -0.00342805]])

# %%
df_original=pe.load_data("active1000")
pe.collaborative_filtering(df_original)
# Out:
# Iteration: 1
# Train mse: 0.602748759135169
# Test mse: 0.6907630909526347
# Iteration: 2
# Train mse: 0.53610365727957
# Test mse: 0.6436531547766763
# Iteration: 5
# Train mse: 0.5137517300417862
# Test mse: 0.6284506222458724
# Iteration: 10
# Train mse: 0.510545477283945
# Test mse: 0.6253356672690465
# Iteration: 25
# Current iteration: 10
# Train mse: 0.5097223411659852
# Test mse: 0.6241964711028141
# Iteration: 50
# Current iteration: 10
# Current iteration: 20
# Train mse: 0.5096533175230455
# Test mse: 0.6240226790284084
# Iteration: 100
# Current iteration: 10
# Current iteration: 20
# Current iteration: 30
# Current iteration: 40
# Current iteration: 50
# Train mse: 0.5096314895175668
# Test mse: 0.6240175882834343

# %%
def item_cosine_similarity(model):
    sim = model.item_vecs.dot(model.item_vecs.T)
    norms = np.array([np.sqrt(np.diagonal(sim))])
    return sim / norms / norms.T

als_item_sim = item_cosine_similarity(best_als_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mariu/dev/school/TDT4215/tdt4215-2022/ratings.ipynb Cell 20' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/mariu/dev/school/TDT4215/tdt4215-2022/ratings.ipynb#ch0000019?line=2'>3</a>     norms = np.array([np.sqrt(np.diagonal(sim))])
#       <a href='vscode-notebook-cell:/Users/mariu/dev/school/TDT4215/tdt4215-2022/ratings.ipynb#ch0000019?line=3'>4</a>     return sim / norms / norms.T
# ----> <a href='vscode-notebook-cell:/Users/mariu/dev/school/TDT4215/tdt4215-2022/ratings.ipynb#ch0000019?line=5'>6</a> als_item_sim = item_cosine_similarity(best_als_model)
#
# NameError: name 'best_als_model' is not defined

# %%
def user_cosine_similarity(model):
    sim = model.user_vecs.dot(model.user_vecs.T)
    norms = np.array([np.sqrt(np.diagonal(sim))])
    return sim / norms / norms.T

als_user_sim = user_cosine_similarity(best_als_model)

# %%
df_ext[df_ext['uid'] == 132]
# Out:
#         uid   tid  normalized_activeTime
# 23      132     1               0.032294
# 557     132     5               0.026726
# 1163    132     8               0.128062
# 1361    132     9               0.006682
# 1613    132    11               0.057906
# ...     ...   ...                    ...
# 655564  132  8221               0.123608
# 655567  132  8222               0.099109
# 655571  132  8223               0.143653
# 655581  132  8224               0.042316
# 655584  132  8225               0.001114
#
# [696 rows x 3 columns]

# %%
def evaluate(pred, actual, k):
    """
    Evaluate recommendations according to recall@k and ARHR@k
    """
    total_num = len(actual)
    tp = 0.
    arhr = 0.
    for p, t in zip(pred, actual):
        if t in p:
            tp += 1.
            arhr += 1./float(p.index(t) + 1.)
    recall = tp / float(total_num)
    arhr = arhr / len(actual)
    print("Recall@{} is {:.4f}".format(k, recall))
    print("ARHR@{} is {:.4f}".format(k, arhr))

# %%
# Choose random user to recommend articles to
test_user_idx = df_ext['uid'][132]
test_article_idx = df_ext['tid'][12204]

# %%
def display_top_k_articles_from_item(similarity, mapper, article_idx):
    article_indices = np.argsort(similarity[article_idx, :])[::-1]
    rec_art = []
    for i in range(0, 10):
        rec_art.append(mapper[mapper['tid'] == article_indices[i]].head(1)['title'].values[0])
    return rec_art

rec_art_items = display_top_k_articles_from_item(als_item_sim, mapper, test_article_idx)

# %%
def display_top_k_articles_from_user(similarity, mapper, user_idx):
    user_indices = np.argsort(similarity[user_idx, :])[::-1]
    rec_art = []
    for i in range(0, 10):
        uids = mapper[mapper['uid'] == user_indices[i]]
        # If the user has already seen the article, don't add it
        if mapper[mapper['uid'] == user_idx]:
            continue
        rec_art.append(mapper[mapper['uid'] == user_indices[i]].head(1)['title'].values[0])
    return rec_art

rec_art_users = display_top_k_articles_from_user(als_user_sim, mapper, test_user_idx)
# Out:
# 1000

# %%
rec_art_items
# Out:
# ['Bussen skal være et gode for byens innbyggere, ikke en trussel',
#  'Konkurs i kles- og interiørbutikk',
#  'Kraftig omgangssyke stenger hotell i Ringerike',
#  '- Vi bor på ei ganske tykk jordskorpe i Trøndelag',
#  'Her gjerdes hotellet inn',
#  'Hus fylt av skatter',
#  'Tysk politi svarte nett-troll etter påkjørsel i Heidelberg',
#  '- Folket i Trondheim henger to år etter Oslo',
#  'Slik skal Trondheim bli gründerhovedstaden',
#  'Hurtigruteskip må vaskes ned etter magesjau']

# %%
rec_art_users
# Out:
# ['Norges landslagssjef ville ha russisk leder utestengt',
#  'Iiiiiiiiiskaldt nyttårsbad',
#  '- Dette er pinlig',
#  'Her laver snøen ned',
#  'Iiiiiiiiiskaldt nyttårsbad',
#  'Norges landslagssjef ville ha russisk leder utestengt',
#  'Eriksson kan måtte tilbakebetale etterlønn',
#  'Norges landslagssjef ville ha russisk leder utestengt',
#  'Kvinne omkom i ulykke på E39',
#  'Norges landslagssjef ville ha russisk leder utestengt']

# %%
mapper
# Out:
#            eventId              category  activeTime  \
# 0       1500434790  100sport|vintersport   17.000000
# 1        161256052  100sport|vintersport   44.359582
# 2        969112529  100sport|vintersport   44.359582
# 3       2032510999  100sport|vintersport  110.000000
# 4       2036417609  100sport|vintersport   44.359582
# ...            ...                   ...         ...
# 679350  1534817466         pluss|nyheter   44.359582
# 679351   930926235     nyheter|trondheim   44.359582
# 679352   509895783     nyheter|trondheim  127.000000
# 679353   286823079       nyheter|okonomi   44.359582
# 679354  1950296327                  None   44.359582
#
#                                                     title  \
# 0       Norges landslagssjef ville ha russisk leder ut...
# 1       Norges landslagssjef ville ha russisk leder ut...
# 2       Norges landslagssjef ville ha russisk leder ut...
# 3       Norges landslagssjef ville ha russisk leder ut...
# 4       Norges landslagssjef ville ha russisk leder ut...
# ...                                                   ...
# 679350     - Hijab-bruk uttrykk for min personlige frihet
# 679351  - Priskrigen på smågodt er den store snakkisen nå
# 679352                     Nettmøte: Slik lever du billig
# 679353                             Kafé på Sirkus konkurs
# 679354                                        Gjestfrihet
#
#                                                       url  \
# 0       http://adressa.no/100sport/langrenn_old/norges...
# 1       http://adressa.no/100sport/langrenn_old/norges...
# 2       http://adressa.no/100sport/langrenn_old/norges...
# 3       http://adressa.no/100sport/langrenn_old/norges...
# 4       http://adressa.no/100sport/langrenn_old/norges...
# ...                                                   ...
# 679350  http://adressa.no/pluss/nyheter/2016/03/09/hij...
# 679351  http://adressa.no/nyheter/trondheim/2016/03/09...
# 679352  http://adressa.no/nyheter/trondheim/2015/11/10...
# 679353  http://adressa.no/nyheter/okonomi/article10382...
# 679354      http://adressa.no/meninger/article1369292.ece
#
#                                              userId               publishtime  \
# 0       cx:10k2wzm1b3jsk2y5ym1utnjo97:2kefzqaxe9jx7  2017-01-01T17:01:11.000Z
# 1            cx:1323088975693404397604:wi004nwg1lgv  2017-01-01T17:01:11.000Z
# 2          cx:13248361004781723078120:2wmidk0ara9mw  2017-01-01T17:01:11.000Z
# 3           cx:1325622642378828560344:30ntt9pj2p3ss  2017-01-01T17:01:11.000Z
# 4           cx:1351161220132407421422:103o91wtrkqso  2017-01-01T17:01:11.000Z
# ...                                             ...                       ...
# 679350    cx:z5nmgvym79d91yxajr8rncjp3:dd23bgkvv19x  2016-03-09T15:30:28.000Z
# 679351    cx:z5nmgvym79d91yxajr8rncjp3:dd23bgkvv19x  2016-03-09T21:19:48.000Z
# 679352    cx:z5nmgvym79d91yxajr8rncjp3:dd23bgkvv19x  2015-11-10T12:44:52.000Z
# 679353    cx:zdxhidle29xquzztafvsik92:2w17zz40qj619  2014-11-24T21:00:13.000Z
# 679354    cx:zdxhidle29xquzztafvsik92:2w17zz40qj619  2009-08-17T12:02:03.000Z
#
#               time                                documentId  \
# 0       1483293374  70a19fd7c9f6827feb3eb4f3df95121664491fa7
# 1       1483294671  70a19fd7c9f6827feb3eb4f3df95121664491fa7
# 2       1483305285  70a19fd7c9f6827feb3eb4f3df95121664491fa7
# 3       1483291064  70a19fd7c9f6827feb3eb4f3df95121664491fa7
# 4       1483302979  70a19fd7c9f6827feb3eb4f3df95121664491fa7
# ...            ...                                       ...
# 679350  1488738821  154105d1bd7992f034d40e77003d410f9bf36760
# 679351  1488808884  8c937275e14fe4998a749e28360ece8f763cddc5
# 679352  1489755626  6725270793f7270a864e5da5333aef84059551ed
# 679353  1486763975  a06ce456d134fbc0e5b508d8efd544671283bc78
# 679354  1490547193  e5718ec09c44b4c9cd110ffce645919956834910
#
#         normalized_activeTime  uid    tid
# 0                    0.017817    1      1
# 1                    0.048285   14      1
# 2                    0.048285   20      1
# 3                    0.121381   21      1
# 4                    0.048285   45      1
# ...                       ...  ...    ...
# 679350               0.048285  998  20340
# 679351               0.048285  998  20341
# 679352               0.140312  998  20342
# 679353               0.048285  999  20343
# 679354               0.048285  999  20344
#
# [679355 rows x 12 columns]
